# %%
 #save LLR recon with multiple splits
 
import numpy as np
import h5py


# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA/'
DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot/'
# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C6/'
# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C12/'
# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C16/'

imgs=[]
imgs_2=[]
# file='CEST_LLR_recons_splits_1of2_Reps_0_17_RO_0_114_1x5x5_r_0.01_i_20_2D_kdat_3D_R34_C44_1shot_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file='CEST_LLR_recons_splits_1of2_Reps_0_17_RO_0_114_1x5x5_r_0.01_i_30_2D_kdat_3D_R34_C44_1shot_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file='CEST_LLR_recons_splits_1of2_Reps_0_17_RO_0_114_1x5x5_r_0.01_i_30_R34_C44_3shot_us_Cart_3_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file='CEST_LLR_recons_splits_1of2_Reps_0_17_RO_0_114_1x5x5_r_0.01_i_30_3shot_us_Cart_3x1_yshift_True_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_17_34_RO_0_114_1x5x5_r_0.01_i_20_2D_kdat_3D_R34_C44_1shot_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_17_34_RO_0_114_1x5x5_r_0.01_i_30_2D_kdat_3D_R34_C44_1shot_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_17_34_RO_0_114_1x5x5_r_0.01_i_30_R34_C44_3shot_us_Cart_3_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_17_34_RO_0_114_1x5x5_r_0.01_i_30_3shot_us_Cart_3x1_yshift_True_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_120_1x5x5_r_0.06_i_30_R26_C58_C12_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C12.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_120_1x5x5_r_0.06_i_30_R26_C58_C12_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C12.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_120_1x5x5_r_0.06_i_30_R26_C58_C6_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C6.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_120_1x5x5_r_0.06_i_30_R26_C58_C6_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C6.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_120_1x5x5_r_0.01_i_30_R26_C58_C6_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C6.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_120_1x5x5_r_0.01_i_30_R26_C58_C6_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C6.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_120_1x5x5_r_5e-05_i_30_R26_C58_C6_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C6.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_120_1x5x5_r_5e-05_i_30_R26_C58_C6_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C6.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_120_1x5x5_r_0.06_i_30_R26_C58_C12_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C12.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_120_1x5x5_r_0.06_i_30_R26_C58_C12_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C12.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_120_1x5x5_r_0.01_i_30_R26_C58_C16_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C16.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_120_1x5x5_r_0.01_i_30_R26_C58_C16_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C16.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_114_1x5x5_r_0.01_i_30_R34_C52_3Shot_us_Cart_3x1_yshift_False_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_114_1x5x5_r_0.01_i_30_R34_C52_3Shot_us_Cart_3x1_yshift_False_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_114_1x5x5_r_0.01_i_30_R34_C52_3Shot_us_CAIP_3x2_yshift_False_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_114_1x5x5_r_0.01_i_30_R34_C52_3Shot_us_CAIP_3x2_yshift_False_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
# file  ='CEST_LLR_recons_splits_1of2_Reps_0_13_RO_0_114_1x5x5_r_0.01_i_30_R34_C52_3Shot_us_CAIP_3x2_yshift_True_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
# file_2='CEST_LLR_recons_splits_2of2_Reps_13_26_RO_0_114_1x5x5_r_0.01_i_30_R34_C52_3Shot_us_CAIP_3x2_yshift_True_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
# RO_start=0
# RO_end=114

with h5py.File(DATA_DIR+file,'r')as f:
    # keys=list(f.keys())
    # for k in f.keys():
    #     imgs.append(f[k][:])
    # imgs=np.stack(([f[k][:] for k in f.keys()]),axis=0)
    for RO_idx in range(RO_start,RO_end): 
        imgs.append(f[f'CEST_recon_RO_idx_{RO_idx}'][:])
imgs=np.asarray(imgs)
imgs=np.transpose(imgs,(-3,-2,-1,-4))
print('imgs shape after transpose:',imgs.shape)
with h5py.File(DATA_DIR+file_2,'r')as f:
    # for k in f.keys():
        # imgs_2.append(f[k][:])
    for RO_idx in range(RO_start,RO_end): 
        imgs_2.append(f[f'CEST_recon_RO_idx_{RO_idx}'][:])       
imgs_2=np.asarray(imgs_2)
imgs_2=np.transpose(imgs_2,(-3,-2,-1,-4))
print('imgs_2 shape after transpose:',imgs_2.shape)
imgs=np.concatenate((imgs,imgs_2),axis=0)
isnan=np.isnan(imgs).any()
print('is Nan:',isnan)
if isnan:
    imgs=np.nan_to_num(abs(imgs), copy=False, nan=0.0, posinf=0.0, neginf=0.0)
print('imgs shape after concatenation:',imgs.shape)
del imgs_2



file=file.replace("splits_1of2_Reps_0_13", "Reps_0_26")
# file=file.replace("splits_1of2_Reps_0_17", "Reps_0_34")

file=file.replace(".h5", "_imgs.h5")
with h5py.File(DATA_DIR+file,'w') as f:
    f.create_dataset('imgs',data=abs(imgs))
del imgs

print('file saved as ' + DATA_DIR + file)
# Out:
# imgs shape after transpose: (17, 28, 96, 114)
# imgs_2 shape after transpose: (17, 28, 96, 114)
# is Nan: False
# imgs shape after concatenation: (34, 28, 96, 114)
# file saved as /home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot/CEST_LLR_recons_Reps_0_26_RO_0_114_1x5x5_r_0.01_i_30_R34_C52_3Shot_us_CAIP_3x2_yshift_False_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot_imgs.h5

# %%
 #save Sense recon 

import numpy as np
import h5py
# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA/'
# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot/'
# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C6/'
# DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C12/'
DATA_DIR='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C16/'


imgs=[]
# file='CEST_SENSE_recons_Reps_0_34_r_0.01_i_30_2D_kdat_3D_R34_C44_1shot_mps_c_0.8_t0.05_w_24_kw_6_sp_ksp.h5'
# file='CEST_SENSE_recons_Reps_0_34_r_0.01_i_30_2D_kdat_3D_R34_C44_1shot_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5' #SENSE recon (good mps)
# file='CEST_SENSE_recons_Reps_0_34_r_0.01_i_30_R34_C44_3shot_us_Cart_3_mps_c_0_t0.05_w_24_kw_6_sp_ksp.h5'
# file='CEST_SENSE_recons_Reps_0_2_r_0.01_i_30_3Shot_us_Cart_3x1_yshift_False_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
# file='CEST_SENSE_recons_Reps_0_26_r_0.01_i_30_3Shot_us_CAIP_3x2_yshift_False_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R34_C52_3Shot.h5'
# file='CEST_SENSE_recons_Reps_0_26_r_0.001_i_30_kdat_2D_R26_C58_C6_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C6.h5'
# file='CEST_SENSE_recons_Reps_0_26_r_0.001_i_30_kdat_2D_R26_C58_C12_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C12.h5'
file='CEST_SENSE_recons_Reps_0_26_r_0.001_i_30_kdat_2D_R26_C58_C16_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C16.h5'
RO_start=0
RO_end=120
# RO_end=114
with h5py.File(DATA_DIR+file,'r')as f:
    # print(f.keys())
    # imgs=np.stack(([f[k][:] for k in f.keys()]),axis=0)
    for RO_idx in range(RO_start,RO_end): 
        imgs.append(f[f'CEST_recon_RO_idx_{RO_idx}'][:])
    # for k in f.keys():
    #     imgs.append(f[k][:])
imgs=np.asarray((imgs))
imgs=np.transpose(abs(imgs),(-3,-2,-1,-4))
print('SENSE recon shape after transpose:',imgs.shape)

file=file.replace(".h5", "_imgs.h5")
with h5py.File(DATA_DIR+file,'w') as f:
    f.create_dataset('imgs',data=abs(imgs))
del imgs

print('file saved as ' + DATA_DIR + file)
# Out:
# SENSE recon shape after transpose: (26, 48, 120, 120)
# file saved as /home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C16/CEST_SENSE_recons_Reps_0_26_r_0.001_i_30_kdat_2D_R26_C58_C16_mps_c_0.9_t0.05_w_36_kw_6_sp_ksp_3D_R26_C58_C16_imgs.h5

# %%
#h5 info (Total acceleration)
import h5py
import numpy as np 
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C12/kdat_3D_R26_C58_CAIP12.h5','r') as f:
with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C6/kdat_3D_R26_C58_C6.h5','r') as f:
    print('kdat keys:',list(f.keys()))
    print('kdat01 shape:',f['kdat_01'].shape)
    print('kdat02shape:',f['kdat_02'].shape)
    print('ref shape :',f['ref'].shape)
    kdat_01=f['kdat_01'][0,29,...]
    # kdat_01=kdat_01[np.newaxis,...]
    # ref=f['ref'][...]
    # print('kdat_01 shape after adding new axis:',kdat_01.shape)
    # with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C12/kdat_3D_R26_C58_CAIP12_S0.h5','w') as sf:
    #     sf.create_dataset('kdat_01',data=kdat_01[:])
    #     sf.create_dataset('ref',data=ref[:])
    # print (np.count_nonzero(abs(kdat_01)>0)/np.size(kdat_01))
    print (np.size(kdat_01)/np.count_nonzero(abs(kdat_01)>0))
    np.info(kdat_01)

    # print (abs(kdat_01[10:30,60,120]))
# Out:
# kdat keys: ['kdat_01', 'kdat_02', 'ref']
# kdat01 shape: (13, 58, 48, 120, 120)
# kdat02shape: (13, 58, 48, 120, 120)
# ref shape : (58, 36, 32, 64)
# 7.669773635153129
# class:  ndarray
# shape:  (48, 120, 120)
# strides:  (115200, 960, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x7985d5da0010
# byteorder:  little
# byteswap:  False
# type: complex64

# %%
#extract S0 + ifft 
import h5py
import sigpy as sp
import numpy as np 

# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C6/kdat_3D_R26_C58_C6_Read.h5','r') as f:
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/GRAPPA3_ACS/ACS_3D_C52_2.h5','r') as f:
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot//kdat_3D_R1_C52_3Shot.h5','r') as f:
file='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot/kdat_3D_R34_C52_3Shot.h5'
with h5py.File(file,'r') as f:
    print('kdat keys:',list(f.keys()))
    print('shape:',f['kdat_01'].shape)
    dat=f['kdat_01'][0,...]
    dat=sp.ifft(dat,axes=[-3,-2,-1])
file=file.replace('R34','R1')
file=file.replace('3Shot.','3Shot_ifft.')
with h5py.File(file,'w')as f:
    f.create_dataset('imgs',data=dat[:])
# Out:
# kdat keys: ['kdat_01', 'kdat_02']
# shape: (17, 52, 28, 96, 114)

# %%
##save Ifft for full sampled data 
import numpy as np
import sigpy as sp
import h5py
file='/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot/kdat_3D_R34_C52_3Shot.h5'
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_APT_C6/kdat_3D_R26_C58_C6_Read.h5','r') as f:
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/GRAPPA3_ACS/ACS_3D_C52_2.h5','r') as f:
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot//kdat_3D_R1_C52_3Shot.h5','r') as f:
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot/kdat_3D_R34_C52_3Shot.h5','r') as f:
with h5py.File(file,'r') as f:
    print('kdat keys:',list(f.keys()))
    imgs=np.concatenate([f[k][:] for k in f.keys()],axis=0)
    print('concatenated imgs shape',imgs.shape)
    imgs=sp.ifft(imgs,axes=[-1,-2,-3])
    imgs=sp.rss(imgs,axes=-4)
    print('rss imgs shape',imgs.shape)
with h5py.File(file.replace('.h5','_imgs.h5'),'w') as f:
    f.create_dataset('imgs', data=abs(imgs))

    # print(np.info(f['imgs'][:]))
#     imgs=f['imgs'][:]
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA_06052026/CEST_GRAPPA3_3Shot/kdat_3D_R1_C52_3Shot_ifft_imgs.h5','w') as f:
#     f.create_dataset('imgs', data=abs(imgs))
#     imgs=np.concatenate([f[k][:] for k in f.keys()],axis=0)
# with h5py.File('/home/vault/iwbi/iwbi112h/CEST_DATA/ifft_recon_3shot_imgs.h5','w') as f:
#     f.create_dataset('imgs',data=imgs)
# Out:
# kdat keys: ['kdat_01', 'kdat_02']
# concatenated imgs shape (34, 52, 28, 96, 114)
# rss imgs shape (34, 28, 96, 114)
